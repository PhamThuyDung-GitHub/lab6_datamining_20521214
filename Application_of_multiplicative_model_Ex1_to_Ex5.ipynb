# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot as plt
from pylab import rcParams
import pandas as pd

# %%
# Example 1: Google Trends, number of searches of the word "vacation", time series shows seasonality
df_vacation = pd.read_csv(r'C:\Users\ungdu\Downloads\lab6_datamining_20521214\df_vacation.csv', parse_dates=['Month'], index_col=0)
ts1 = df_vacation['Num_Search_Vacation']

# %%
# Decompose the time series
rcParams['figure.figsize'] = 6, 8
plt.style.use('bmh')
result = seasonal_decompose(ts1, model='multiplicative', period=12)
result.plot()
plt.show()

# %%
# Example 2: Furniture sales in Millions of Dollars (adjusted to July 2019 prices)
df_furniture = pd.read_csv(r'C:\Users\ungdu\Downloads\lab6_datamining_20521214\df_furniture.csv', parse_dates=['Month'], index_col=0)
ts2 = df_furniture['furniture_price_adjusted']

# %%
# Decompose the time series
rcParams['figure.figsize'] = 6, 8
plt.style.use('bmh')
result = seasonal_decompose(ts2, model='multiplicative', period=12)
result.plot()
plt.show()

# %%
# Example 3: Adjusted Close Price for Bank of America
df_bac = pd.read_csv(r'C:\Users\ungdu\Downloads\lab6_datamining_20521214\df_bankofamerica.csv', parse_dates=['Date'], index_col=0)
ts3 = df_bac['Adj Close Price']

# %%
# Decompose the time series
rcParams['figure.figsize'] = 6, 8
plt.style.use('bmh')
result = seasonal_decompose(ts3, model='multiplicative', period=365)
result.plot()
plt.show()

# %%
# Example 4: Adjusted Close Price for J.P. Morgan
df_jpm = pd.read_csv(r'C:\Users\ungdu\Downloads\lab6_datamining_20521214\df_jpmorgan.csv', parse_dates=['Date'], index_col=0)
ts4 = df_jpm['Adj Close Price']

# %%
# Decompose the time series
rcParams['figure.figsize'] = 6, 8
plt.style.use('bmh')
result = seasonal_decompose(ts4, model='multiplicative', period=365)
result.plot()
plt.show()

# %%
# Example 5: Average Temperature of St. Louis
df_temp = pd.read_csv(r'C:\Users\ungdu\Downloads\lab6_datamining_20521214\df_temp.csv', parse_dates=['Date'], index_col=0)
ts5 = df_temp['Value']

# %%
# Decompose the time series
rcParams['figure.figsize'] = 6, 8
plt.style.use('bmh')
result = seasonal_decompose(ts5, model='multiplicative', period=12)
result.plot()
plt.show()
