# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read in data
bac = pd.read_csv(r'C:\Users\ungdu\Downloads\bac.csv')
print(bac.head())
# Out:
#      Date  Adj Close Price
# 0  1/2/90         1.711862
# 1  1/3/90         1.725632
# 2  1/4/90         1.688917
# 3  1/5/90         1.652200
# 4  1/8/90         1.661379

# %%
# Check for missing values
print(bac.isna().sum())

# Display column names
print(bac.columns)
# Out:
# Date               0
# Adj Close Price    0
# dtype: int64
# Index(['Date', 'Adj Close Price'], dtype='object')

# %%
# Convert to datetime
from datetime import datetime
bac['Date'] = pd.to_datetime(bac['Date'])

# Set index, use inplace=True
bac.set_index('Date', inplace=True)
print(bac.head())
# Out:
# C:\Users\ungdu\AppData\Local\Temp\ipykernel_1696\4077739515.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bac['Date'] = pd.to_datetime(bac['Date'])
#             Adj Close Price
# Date
# 1990-01-02         1.711862
# 1990-01-03         1.725632
# 1990-01-04         1.688917
# 1990-01-05         1.652200
# 1990-01-08         1.661379

# %%
# Provide the descriptive (summary) statistics
# Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset's distribution, excluding NaN values.
# Percentile values (quantile 1, 2, and 3) on numeric values
print(bac.describe())
# Out:
#        Adj Close Price
# count      7507.000000
# mean         16.313610
# std          10.910945
# min           0.699197
# 25%           7.526543
# 50%          14.318160
# 75%          23.844322
# max          43.195049

# %%
# Plot the time series for Bank of America Adjusted Close Price
plt.style.use('classic')
ax = bac.plot(color='red', grid=True, linewidth=3)
ax.set_xlabel('Year')
ax.set_ylabel('Adjusted Close Price')
ax.set_title('Bank of America Adjusted Close Price')
plt.show()

# %%
# Plot histogram (frequency of counts), change num of bins to see different plots
bac.plot(kind='hist', bins=50, color='violet', grid=True)
plt.show()

# %%
# Saving the dataframe
bac.to_csv('df_bankofamerica.csv')
